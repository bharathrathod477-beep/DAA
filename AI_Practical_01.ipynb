# %% [markdown]
# <a href="https://colab.research.google.com/github/bharathrathod477-beep/DAA/blob/main/AI_Practical_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
[]
fruits = ["apple", "banana", "cherry"]
for fruit in fruits:
    print(fruit)

# %%
[]

[]
for i in range(1,6):
 print(i)

# %%
[]
count =1

while count <=5:
  print(count)
  count +=1 #increase count by 1

# %%
  fruits = ["apple","banana", "cherry"]
print(fruits[0])  #first element
print(fruits[-2]) #last element

# %%
numbers = [10, 20,30, 40, 50]
print(numbers[1:4])
print(numbers[:3])
print(numbers[2:])

# %% [markdown]
# adding

# %%
   fruits = ["apple", "banana"]
   fruits.append("cherry")
   fruits.insert(1, "orange")
   print(fruits)

# %%
numbers = [1,2,3,4]
print(numbers[1:-2])

# %%
fruits =["apple","banana","cherry"]
fruits.remove("banana")
fruits.pop(1)
print(fruits)

# %%
numbers =[5,2,9,1,7]
print(len(numbers))
print(max(numbers))
print(min(numbers))
numbers.sort()
print(numbers)
numbers.reverse()
print(numbers)

# %% [markdown]
# **count & index**

# %%
data =(1,2,2,  3,4,2)
print(data.count(2))
print(data.index(3))

# %% [markdown]
# concatenation (joining)

# %%
str1 = "hello"
str2 = "World"
result = str1 + "" +str2
print(result)
# Out:
# helloWorld

# %% [markdown]
# repetition

# %%
word ="hi!"
print(word * 3)
# Out:
# hi!hi!hi!

# %%
def greet(name):
  return name

print(greet("bharath"))
print(greet("ramavath"))
# Out:
# bharath
# ramavath

# %%
def f1(num1,num2):
  add=num1 + num2
  sub=num1 - num2
  divide=num1 / num2
  return add,sub,divide

result=f1 (6,2)
print("add :",result[0])
print("sub :",result[1])
print("divide:",result[2])
# Out:
# add : 8
# sub : 4
# divide: 3.0

# %%
def factorial(n):
    if n < 0:
        return "Factorial is not defined for negative numbers"
    result = 1
    for i in range(1, n + 1):
        result *= i
    return result

print(factorial(5))
# Out:
# 120

# %%
import math

def red(r):
    area = math.pi * r**2
    circumference = 2 * math.pi * r
    return area, circumference

radius = float(input('Enter the radius: '))
print('Area and circumference of circle is:', red(radius))
# Out:
# Enter the radius: 24
# Area and circumference of circle is: (1809.5573684677208, 150.79644737231007)

# %%
base = float(input("enter the base of thr triangle"))
heghit = float (input("enter the height of thr triangle"))
# Out:
# enter the base of thr triangle3
# enter the height of thr triangle6

# %%
try:
   #code that may raise an exception
   num = int (input("enter a number:"))
   result = 10 / num
   print("result:", result)

expcept ZeroDivisionError:
 print("error: Cannot divide by zero!")

expcept ZeroDivisionError:
 print("error: Invalid input! Please enter a number. ")

finally:
  print("This will always execute, whether there is an error or not.")
# Out:
#   File "/tmp/ipykernel_787/2417698195.py", line 7
#     expcept ZeroDivisionError:
#     ^
# SyntaxError: expected 'except' or 'finally' block

# %%
ZeroDivisionError
print(10 / 0)

ValueError
num = int("abc")

TypeError
print("hello" + 5)

Index Number
print("Error: Index is out of range.")

# %%
try:
   x = int("abc")
exceptcept valueerror

# %% [markdown]
# 1. Create a text file and save it

# %%
#Create  and save a text file
with open ("students.txt","w") as file:
  file.write("This is a new file created in google colab./n")
print("File created and initial content saved.")

# %% [markdown]
# open the file and read its content

# %%
#Open the file and read its contest
with open ("students.txt", "r") as file:
  content = file.read()
print("file content:/n", content )

# %%
#Write student data into the file
with open("students.txt","w") as file:
  file.write("Roll. no | Name     |Age | Gender\n")
  file.write("---------------------------------\n")
  file.write("101      |Alice     |20  |Female\n")
  file.write("102      |bob       |21  |Male\n ")
  file.write("103      |bharath   |22  |Male\n")
  print("student data written successfully.")

# %%
#Open the files again and read updated contant
with open("students.txt", "r") as file:
  content = file.read()
print("file content:/n", content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_787/2743588716.py in <cell line: 0>()
#       1 #Open the files again and read updated contant
# ----> 2 with open("students.txt", "r") as file:
#       3   content = file.read()
#       4 print("file content:/n", content)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'students.txt'

# %% [markdown]
# Download the file from google colab to your PC

# %%
from google.colab import files
files.download("students.txt")

# %% [markdown]
# create a emptylist
# add some books in the list by usig some function

# %% [markdown]
# IMPORT OS

# %%
 #Create your own library
 import os

# %%
LIBARAY

# %%
 #List to hold book dictionaries
 library=[]

# %%
def add_book(title, author,genre, year, status="unread"):
  book ={
      "title":title.strip(),
      "author":author.strip(),
      "genre":genre.strip(),
      "year":int(year),
      "status":status.lower()
  }
  Library.append(book)
  print(f"Book '{title}' added.")

# %%
def list_books(sorted_by_year=False):

if not library:

print("Library is empty.")

return

books sorted(library, key-lambda x: x['year']) if sorted_by_year else library

for idx, book in enumerate(books, start-1):

print(f"(idx). {book['title']} by (book['author']} [{book['genre']}, {book['year']}] {book['status'].capitalize())")

# %% [markdown]
# SEARCH AUTHOR NAME

# %%
def search_by_author(author_name):
  return [book for book in libaray if author_name.lower() in book['author'].lower()]

# %% [markdown]
# DELETE BOOK

# %%
def delete_book(title):
  global libaray
  libaray = list(filter(lambda book: book ['title'].lower() != title.lower(), library))
  print(F"Book titled '{title}' has been removed if it existed.")
